# %% [markdown]
# <a href="https://colab.research.google.com/github/daseul0719/NLP_2024/blob/main/12_lexicaldiversity_aesop4children.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/ms624atyale/NLP_2024
# Out:
# Cloning into 'NLP_2024'...
# remote: Enumerating objects: 611, done.
# remote: Counting objects: 100% (446/446), done.
# remote: Compressing objects: 100% (264/264), done.
# remote: Total 611 (delta 296), reused 269 (delta 180), pack-reused 165 (from 1)
# Receiving objects: 100% (611/611), 15.96 MiB | 14.34 MiB/s, done.
# Resolving deltas: 100% (345/345), done.

# %%
# %cd /content/NLP_2024/Sample_ClassActivity
# Out:
# /content/NLP_2024/Sample_ClassActivity

# %% [markdown]
# ### <font color = 'pink'> 🔋 🔌 **Now** move "PG Aesop NoQuotes' file under [PG Aesop NoQuotes folder] **to** [the sample_data folder]!

# %%
file = open("/content/NLP_2024/Sample_ClassActivity/1_Aesop4Children_Base4CSV_UTF8_Sample4ClassActivity.txt", 'rt')
txt = file.read()
print(txt)
file.close() #Using this close()function, you are no longer using your text file of the current workingdirectory with open()function.
# Out:
# THE WOLF AND THE KID
# ...

# %%
# !pip install nltk
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import sent_tokenize
sentence = sent_tokenize(txt)
print('Sentence Tokenized: %s' %sentence)
# Out:
# Sentence Tokenized: ['\nTHE WOLF AND THE KID\nThere was once a little Kid whose growing horns made him think he was a grown-up Billy Goat and able to take care of himself.', 'So one evening when the flock started home from the pasture and his mother called, the Kid paid no heed and kept right on nibbling the tender grass.', 'A little later when he lifted his head, the flock was gone.', 'He was all alone.', 'The sun was sinking.', 'Long shadows came creeping over the ground.', 'A chilly little wind came creeping with them making scary noises in the grass.', 'The Kid shivered as he thought of the terrible Wolf.', 'Then he started wildly over the field, bleating for his mother.', 'But not half-way, near a clump of trees, there was the Wolf!', 'The Kid knew there was little hope for him.', '"Please, Mr. Wolf," he said trembling, "I know you are going to eat me.', 'But first please pipe me a tune, for I want to dance and be merry as long as I can."', 'The Wolf liked the idea of a little m
# ...

# %% [markdown]
# ###🚫⤵️ <font color = 'red'>**Tokenization _not_ recommended**</font> because of failing to cleaning esape characters, punctuations, etc.

# %%
file = open("/content/NLP_2024/Sample_ClassActivity/PG_Aesop_Fables.txt", 'rt')

obj = file.read().replace('\n',' ').replace('_','').replace("“", "").replace("”","")
obj.split()
# Out:
# ['There',
#  'was',
#  'once',
#  'a',
#  'little',
#  'Kid',
#  'whose',
#  'growing',
#  'horns',
#  'made',
#  'him',
#  'think',
#  'he',
#  'was',
#  'a',
#  'grown-up',
#  'Billy',
#  'Goat',
#  'and',
#  'able',
#  'to',
#  'take',
#  'care',
#  'of',
#  'himself.',
#  'So',
#  'one',
#  'evening',
#  'when',
#  'the',
#  'flock',
#  'started',
#  'home',
#  'from',
#  'the',
#  'pasture',
#  'and',
#  'his',
#  'mother',
#  'called,',
#  'the',
#  'Kid',
#  'paid',
#  'no',
#  'heed',
#  'and',
#  'kept',
#  'right',
#  'on',
#  'nibbling',
#  'the',
#  'tender',
#  'grass.',
#  'A',
#  'little',
#  'later',
#  'when',
#  'he',
#  'lifted',
#  'his',
#  'head,',
#  'the',
#  'flock',
#  'was',
#  'gone.',
#  'He',
#  'was',
#  'all',
#  'alone.',
#  'The',
#  'sun',
#  'was',
#  'sinking.',
#  'Long',
#  'shadows',
#  'came',
#  'creeping',
#  'over',
#  'the',
#  'ground.',
#  'A',
#  'chilly',
#  'little',
#  'wind',
#  'came',
#  'creeping',
#  'with',
#  'them',
# ...

# %% [markdown]
# ###**<font color = 'red'>Gneral Information**
# Function.	Type	symbols or words	result	example
# RegexpTokenizer()	punctuation	".", ",", "?", "!", ";", ":"	deleted
# apostrophe	"'"	deleted
# word-linking hyphen	"-"	deleted
# phrase-linking hyphen	"--"	deleted
# Capital vs. small	The ones	tokenize	'The', 'ones'
# they're, were having		'they', 're', 'were', 'hav'

# %% [markdown]
# 💡 🔎 **RegexpTokenizer** is a <font color = 'red'>_class_</font>.
# - An example code line:
#   - **from nltk.tokenize import RegexpTokenizer**
#
# - It is part of the nltk.tokenize module and is used for tokenizing text based on regular expression patterns. When you import RegexpTokenizer using this line, you make the RegexpTokenizer class available for use in your Python script or program. You can create instances of this class to tokenize text based on specific regular expression patterns.

# %% [markdown]
# ###🔨 **Replacing capital letters with small characters**

# %%
fl = open("/content/NLP_2024/Sample_ClassActivity/PG_Aesop_Fables.txt", 'rt') #reading using the 'rt'
fl_content = fl.read().lower().replace("\n"," ").replace("\“C", "").replace("\"", "").replace("\“", "").replace("_", "")
with open('Aesop_lower', 'w') as cf:
  cf.write(fl_content)

print(fl_content)
# Out:
# “ there was once a little kid whose growing horns made him think he was a grown-up billy goat and able to take care of himself. so one evening when the flock started home from the pasture and his mother called, the kid paid no heed and kept right on nibbling the tender grass. a little later when he lifted his head, the flock was gone. he was all alone. the sun was sinking. long shadows came creeping over the ground. a chilly little wind came creeping with them making scary noises in the grass. the kid shivered as he thought of the terrible wolf. then he started wildly over the field, bleating for his mother. but not half-way, near a clump of trees, there was the wolf! the kid knew there was little hope for him. please, mr. wolf,\” he said trembling, i know you are going to eat me. but first please pipe me a tune, for i want to dance and be merry as long as i can.the wolf liked the idea of a little music before eating, so he struck up a merry tune and the kid leaped and frisked gaily.
# ...

# %%
# Open the input file in read-text mode ('rt')
fl = open("/content/NLP_2024/Sample_ClassActivity/1_Aesop4Children_Base4CSV_UTF8_Sample4ClassActivity.txt", 'rt')
# Read the content, convert it to lowercase, and replace unwanted characters
fl_content = fl.read().lower().replace("\n", " ").replace("\“", "").replace("\"", "").replace("\”", "").replace("_", "")

# Close the input file
fl.close()

# Write the processed content to a new text file
with open('Aesop_lower.txt', 'w') as cf:  # Ensure .txt extension is added
    cf.write(fl_content)

# Print the processed content to verify
print(fl_content)
# Out:
#  the wolf and the kid there was once a little kid whose growing horns made him think he was a grown-up billy goat and able to take care of himself. so one evening when the flock started home from the pasture and his mother called, the kid paid no heed and kept right on nibbling the tender grass. a little later when he lifted his head, the flock was gone. he was all alone. the sun was sinking. long shadows came creeping over the ground. a chilly little wind came creeping with them making scary noises in the grass. the kid shivered as he thought of the terrible wolf. then he started wildly over the field, bleating for his mother. but not half-way, near a clump of trees, there was the wolf! the kid knew there was little hope for him. please, mr. wolf, he said trembling, i know you are going to eat me. but first please pipe me a tune, for i want to dance and be merry as long as i can. the wolf liked the idea of a little music before eating, so he struck up a merry tune and the kid leaped
# ...

# %%
# 💡💊 Tokenization with RegexpTokeizer

fl = open("/content/Aesop_lower", 'rt') #reading using the 'rt'
obj = fl.read().replace("“ ","").replace("”","")
print(obj)

with open('Aesop_nosym', 'w') as cf:
  cf.write(obj)

from nltk.tokenize import sent_tokenize
sentence = sent_tokenize(obj)
print('Sentence Tokenized: %s' %sentence)

from nltk.tokenize import RegexpTokenizer #RegexpTokenizer as a class
import re                           #대소문자 주의

tok = RegexpTokenizer("[\w]+") # Alert: You cannot use RegexpTokenizer() without argument. You need a regexpression formula.

tk = tok.tokenize(obj)
print('Tokenizing Words with RegexpTokenizer: %s' %tk)

print(' '.join(tk)) #small characters
#alternatively, use the codeline of ' '.join(tkn)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-09f3e1c577f6> in <cell line: 3>()
#       1 # 💡💊 Tokenization with RegexpTokeizer
#       2
# ----> 3 fl = open("/content/Aesop_lower", 'rt') #reading using the 'rt'
#       4 obj = fl.read().replace("“ ","").replace("”","")
#       5 print(obj)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/Aesop_lower'

# %% [markdown]
# Alternatively, you can also do this!

# %%
# Open the input file in read-text mode
fl = open("/content/NLP_2024/Sample_ClassActivity/1_Aesop4Children_Base4CSV_UTF8_Sample4ClassActivity.txt", 'rt')
# Read the content, convert to lowercase, and clean unwanted characters
fl_content = fl.read().replace("\n", " ").replace("\“", "").replace("\"", "").replace("\”", "").replace("_", "")
# Close the input file
fl.close()

# Write the processed content to a new text file
with open('/content/Aesop_upper.txt', 'w') as cf:  # Ensure .txt extension is added
    cf.write(fl_content)

# Print the processed content to verify
print(fl_content)  # Write the cleaned content to the output file
# Out:
#  THE WOLF AND THE KID There was once a little Kid whose growing horns made him think he was a grown-up Billy Goat and able to take care of himself. So one evening when the flock started home from the pasture and his mother called, the Kid paid no heed and kept right on nibbling the tender grass. A little later when he lifted his head, the flock was gone. He was all alone. The sun was sinking. Long shadows came creeping over the ground. A chilly little wind came creeping with them making scary noises in the grass. The Kid shivered as he thought of the terrible Wolf. Then he started wildly over the field, bleating for his mother. But not half-way, near a clump of trees, there was the Wolf! The Kid knew there was little hope for him. Please, Mr. Wolf, he said trembling, I know you are going to eat me. But first please pipe me a tune, for I want to dance and be merry as long as I can. The Wolf liked the idea of a little music before eating, so he struck up a merry tune and the Kid leaped
# ...

# %%
# 💡💊 Tokenization with RegexpTokeizer

nf = open("/content/Aesop_upper.txt", 'rt') #reading the new file as nf using the 'rt'
obj = nf.read().lower()
# Regular expression to match a quotation mark followed by a space
f_text = re.sub(r'^\s+', '"', obj) #fixed text as f_text
print(f_text)
print(f_text)

with open('/content/Aesop_lower_nosymbol.txt', 'w') as cf:
  cf.write(obj)

from nltk.tokenize import sent_tokenize
sentence = sent_tokenize(obj)
print('Sentence Tokenized: %s' %sentence)

from nltk.tokenize import RegexpTokenizer #RegexpTokenizer as a class
import re

tok = RegexpTokenizer("[\w]+") # Alert: You cannot use RegexpTokenizer() without argument. You need a regexpression formula.

tk = tok.tokenize(obj)
print('Tokenizing Words with RegexpTokenizer: %s' %tk)

print(' '.join(tk)) #small characters
#alternatively, use the codeline of ' '.join(tkn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-a29bb5848dc5> in <cell line: 6>()
#       4 obj = nf.read().lower()
#       5 # Regular expression to match a quotation mark followed by a space
# ----> 6 f_text = re.sub(r'^\s+', '"', obj) #fixed text as f_text
#       7 print(f_text)
#       8 print(f_text)
#
# NameError: name 're' is not defined

# %% [markdown]
# 💡 Alternatively, you can break RegexpTokenizer("[\w]+") into two seperate codelines:
#
#     - A regular expression pattern is defined within the RegexpTokenize constructor: [\w]+.
#     - This pattern is used for tokenization.
#
# pattern = r'\w+'
#
# retokenize = RegexpTokenizer(pattern)
#
#     - This codeline is designed to match one or more consecutive word characters.

# %%
# !pip install lexical-diversity
from lexical_diversity import lex_div as ld

with open("/content/Aesop_lower_nosymbol.txt", 'rt') as fl:
    fl_content = fl.read().lower()

# Tokenize the content
tok = ld.tokenize(fl_content)
print(tok)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 2.3 MB/s eta 0:00:00
# ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-23e82ba2adb3> in <cell line: 4>()
#       2 from lexical_diversity import lex_div as ld
#       3
# ----> 4 with open("/content/Aesop_lower_nosymbol.txt", 'rt') as fl:
#       5     fl_content = fl.read().lower()
#       6
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/Aesop_lower_nosymbol.txt'

# %%
print(tok[:10])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-2564a2f4fb55> in <cell line: 1>()
# ----> 1 print(tok[:10])
#
# NameError: name 'tok' is not defined

# %%
flt = ld.flemmatize(fl_content) #fast execution of lemmatization

# %%
print(ld.ttr(flt))
# Out:
# 0.38256658595641646

# %% [markdown]
# #📮
# cf. You can also consider eliminating stopwords if you can come up with something decent cause. Try to include this codeline if you want for your information.
# - shortword = re.compile(r'\W*\b\w{1,3}\b') #Remove words less than 3 letters.
